# %%
job = "/B/Bà vú/Bác sĩ/Bảo mẫu/Bệnh nghề nghiệp/Bồi bàn/C/Caddie/Cán bộ/Cảnh sát/Cầu thủ bóng đá/Chuyên viên/Công chức/Công chứng viên/Công nhân/Công tác xã hội/Cửa hàng tiện lợi/D/Diễn viên/Diễn viên võ thuật/Dược sĩ/Đ/Đao phủ/Đầu bếp/Điều dưỡng viên/Điêu khắc đá/G/Gia sư/Giám đốc (doanh nghiệp)/Giám thị/Giảng viên/H/Huấn luyện viên/K/Khảo sát xây dựng/Kiến trúc sư/Kỹ sư tư vấn giám sát/Kỹ thuật hệ thống/L/Lao công/Lập trình viên/Luật sư/M/Mại dâm/N/Nghề nghiệp/Nghề tính toán bảo hiểm/Người bào chữa/Người dẫn chương trình/Người giết mổ gia súc/Người giúp việc/Người hâm mộ/Người mẫu/Người mẫu ảnh/Người mẫu quảng cáo/Nhà làm phim/Nhân viên pha cà phê/Nhiếp ảnh gia/Nữ tu/P/Phóng viên truyền hình/Q/Quản lý xây dựng/Quân sư/S/Siêu sao/Socialite/T/Thằng mõ/Tài tử/Thám tử tư/Thiết kế xây dựng/Thợ hồ/Thợ may/Thợ máy/Thợ mỏ/Thợ rèn sắt/Thợ xây/Thủ thư/Thư ký/Thừa phát lại/Tiệm tạp hóa/Tổng thầu xây dựng/Trợ giúp viên pháp lý/Trưởng làng/Tuyên truyền viên/Tứ dân/Tư tế/Tư vấn xây dựng/V/Võ sĩ giác đấu/X/Xe ôm"
job = job.split('/')
print (job)
# Out:
# ['', 'B', 'Bà vú', 'Bác sĩ', 'Bảo mẫu', 'Bệnh nghề nghiệp', 'Bồi bàn', 'C', 'Caddie', 'Cán bộ', 'Cảnh sát', 'Cầu thủ bóng đá', 'Chuyên viên', 'Công chức', 'Công chứng viên', 'Công nhân', 'Công tác xã hội', 'Cửa hàng tiện lợi', 'D', 'Diễn viên', 'Diễn viên võ thuật', 'Dược sĩ', 'Đ', 'Đao phủ', 'Đầu bếp', 'Điều dưỡng viên', 'Điêu khắc đá', 'G', 'Gia sư', 'Giám đốc (doanh nghiệp)', 'Giám thị', 'Giảng viên', 'H', 'Huấn luyện viên', 'K', 'Khảo sát xây dựng', 'Kiến trúc sư', 'Kỹ sư tư vấn giám sát', 'Kỹ thuật hệ thống', 'L', 'Lao công', 'Lập trình viên', 'Luật sư', 'M', 'Mại dâm', 'N', 'Nghề nghiệp', 'Nghề tính toán bảo hiểm', 'Người bào chữa', 'Người dẫn chương trình', 'Người giết mổ gia súc', 'Người giúp việc', 'Người hâm mộ', 'Người mẫu', 'Người mẫu ảnh', 'Người mẫu quảng cáo', 'Nhà làm phim', 'Nhân viên pha cà phê', 'Nhiếp ảnh gia', 'Nữ tu', 'P', 'Phóng viên truyền hình', 'Q', 'Quản lý xây dựng', 'Quân sư', 'S', 'Siêu sao', 'Socialite', 'T', 'Thằng mõ', 'Tài tử', 'Thám tử tư', 'Thiết k
# ...

# %%
jobs = []
for i in job:
    if len(i) >= 2:
        jobs.append(i)
        
print (jobs)
# Out:
# ['Bà vú', 'Bác sĩ', 'Bảo mẫu', 'Bệnh nghề nghiệp', 'Bồi bàn', 'Caddie', 'Cán bộ', 'Cảnh sát', 'Cầu thủ bóng đá', 'Chuyên viên', 'Công chức', 'Công chứng viên', 'Công nhân', 'Công tác xã hội', 'Cửa hàng tiện lợi', 'Diễn viên', 'Diễn viên võ thuật', 'Dược sĩ', 'Đao phủ', 'Đầu bếp', 'Điều dưỡng viên', 'Điêu khắc đá', 'Gia sư', 'Giám đốc (doanh nghiệp)', 'Giám thị', 'Giảng viên', 'Huấn luyện viên', 'Khảo sát xây dựng', 'Kiến trúc sư', 'Kỹ sư tư vấn giám sát', 'Kỹ thuật hệ thống', 'Lao công', 'Lập trình viên', 'Luật sư', 'Mại dâm', 'Nghề nghiệp', 'Nghề tính toán bảo hiểm', 'Người bào chữa', 'Người dẫn chương trình', 'Người giết mổ gia súc', 'Người giúp việc', 'Người hâm mộ', 'Người mẫu', 'Người mẫu ảnh', 'Người mẫu quảng cáo', 'Nhà làm phim', 'Nhân viên pha cà phê', 'Nhiếp ảnh gia', 'Nữ tu', 'Phóng viên truyền hình', 'Quản lý xây dựng', 'Quân sư', 'Siêu sao', 'Socialite', 'Thằng mõ', 'Tài tử', 'Thám tử tư', 'Thiết kế xây dựng', 'Thợ hồ', 'Thợ may', 'Thợ máy', 'Thợ mỏ', 'Thợ rèn sắt', 'Thợ
# ...

# %%
S = ''
for i in jobs: 
    S = S + "function(callback) {\n\tjobCreate('"+i+"', callback);\n},\n"
print (S)
# Out:
# function(callback) {
# 	jobCreate('Bà vú', callback);
# },
# function(callback) {
# 	jobCreate('Bác sĩ', callback);
# },
# function(callback) {
# 	jobCreate('Bảo mẫu', callback);
# },
# function(callback) {
# 	jobCreate('Bệnh nghề nghiệp', callback);
# },
# function(callback) {
# 	jobCreate('Bồi bàn', callback);
# },
# function(callback) {
# 	jobCreate('Caddie', callback);
# },
# function(callback) {
# 	jobCreate('Cán bộ', callback);
# },
# function(callback) {
# 	jobCreate('Cảnh sát', callback);
# },
# function(callback) {
# 	jobCreate('Cầu thủ bóng đá', callback);
# },
# function(callback) {
# 	jobCreate('Chuyên viên', callback);
# },
# function(callback) {
# 	jobCreate('Công chức', callback);
# },
# function(callback) {
# 	jobCreate('Công chứng viên', callback);
# },
# function(callback) {
# 	jobCreate('Công nhân', callback);
# },
# function(callback) {
# 	jobCreate('Công tác xã hội', callback);
# },
# function(callback) {
# 	jobCreate('Cửa hàng tiện lợi', callback);
# },
# ...

# %%
S = ''
for i in range(200):
    S = S + "function(callback) {\n\tidentificationCreate('"+str(i)+"', callback);\n},\n"
print (S)
# Out:
# function(callback) {
# 	identificationCreate('0', callback);
# },
# function(callback) {
# 	identificationCreate('1', callback);
# },
# function(callback) {
# 	identificationCreate('2', callback);
# },
# function(callback) {
# 	identificationCreate('3', callback);
# },
# function(callback) {
# 	identificationCreate('4', callback);
# },
# function(callback) {
# 	identificationCreate('5', callback);
# },
# function(callback) {
# 	identificationCreate('6', callback);
# },
# function(callback) {
# 	identificationCreate('7', callback);
# },
# function(callback) {
# 	identificationCreate('8', callback);
# },
# function(callback) {
# 	identificationCreate('9', callback);
# },
# function(callback) {
# 	identificationCreate('10', callback);
# },
# function(callback) {
# 	identificationCreate('11', callback);
# },
# function(callback) {
# 	identificationCreate('12', callback);
# },
# function(callback) {
# 	identificationCreate('13', callback);
# },
# function(callback) {
# ...

# %%
S = ''
for i in range(20):
    S = S + "function(callback) {\n\tfamilyCreate(callback);\n},\n"
print (S)
# Out:
# function(callback) {
# 	familyCreate(callback);
# },
# function(callback) {
# 	familyCreate(callback);
# },
# function(callback) {
# 	familyCreate(callback);
# },
# function(callback) {
# 	familyCreate(callback);
# },
# function(callback) {
# 	familyCreate(callback);
# },
# function(callback) {
# 	familyCreate(callback);
# },
# function(callback) {
# 	familyCreate(callback);
# },
# function(callback) {
# 	familyCreate(callback);
# },
# function(callback) {
# 	familyCreate(callback);
# },
# function(callback) {
# 	familyCreate(callback);
# },
# function(callback) {
# 	familyCreate(callback);
# },
# function(callback) {
# 	familyCreate(callback);
# },
# function(callback) {
# 	familyCreate(callback);
# },
# function(callback) {
# 	familyCreate(callback);
# },
# function(callback) {
# 	familyCreate(callback);
# },
# function(callback) {
# 	familyCreate(callback);
# },
# function(callback) {
# 	familyCreate(callback);
# },
# function(callback) {
# 	familyCreate(callback);
# },
# ...

# %%
commune = "Khánh An, Khánh Công, Khánh Cư, Khánh Cường, Khánh Hải, Khánh Hòa, Khánh Hội, Khánh Hồng, Khánh Lợi, Khánh Mậu, Khánh Nhạc, Khánh Phú, Khánh Thành, Khánh Thiện, Khánh Thủy, Khánh Tiên, Khánh Trung, Khánh Vân"
commune = commune.split(', ')
print (commune)
# Out:
# ['Khánh An', 'Khánh Công', 'Khánh Cư', 'Khánh Cường', 'Khánh Hải', 'Khánh Hòa', 'Khánh Hội', 'Khánh Hồng', 'Khánh Lợi', 'Khánh Mậu', 'Khánh Nhạc', 'Khánh Phú', 'Khánh Thành', 'Khánh Thiện', 'Khánh Thủy', 'Khánh Tiên', 'Khánh Trung', 'Khánh Vân']

# %%
S = ''
for i in commune:
    S = S + "function(callback) {\n\tcommuneCreate('"+i+"', callback);\n},\n"
print (S)
# Out:
# function(callback) {
# 	communeCreate('Khánh An', callback);
# },
# function(callback) {
# 	communeCreate('Khánh Công', callback);
# },
# function(callback) {
# 	communeCreate('Khánh Cư', callback);
# },
# function(callback) {
# 	communeCreate('Khánh Cường', callback);
# },
# function(callback) {
# 	communeCreate('Khánh Hải', callback);
# },
# function(callback) {
# 	communeCreate('Khánh Hòa', callback);
# },
# function(callback) {
# 	communeCreate('Khánh Hội', callback);
# },
# function(callback) {
# 	communeCreate('Khánh Hồng', callback);
# },
# function(callback) {
# 	communeCreate('Khánh Lợi', callback);
# },
# function(callback) {
# 	communeCreate('Khánh Mậu', callback);
# },
# function(callback) {
# 	communeCreate('Khánh Nhạc', callback);
# },
# function(callback) {
# 	communeCreate('Khánh Phú', callback);
# },
# function(callback) {
# 	communeCreate('Khánh Thành', callback);
# },
# function(callback) {
# 	communeCreate('Khánh Thiện', callback);
# },
# function(callback) {
# ...

# %%
district = "/Xã, phường thuộc thành phố Ninh Bình(14 tr.)/Xã, thị trấn thuộc huyện Gia Viễn(21 tr.)/Xã, thị trấn thuộc huyện Hoa Lư(11 tr.)/Xã, thị trấn thuộc huyện Kim Sơn(28 tr.)/Xã, thị trấn thuộc huyện Nho Quan(27 tr.)/Xã, phường thuộc thành phố Tam Điệp(9 tr.)/Xã, thị trấn thuộc huyện Yên Khánh(19 tr.)/Xã, thị trấn thuộc huyện Yên Mô(17 tr.)"
for x in '1234567890':
    district = district.replace(x,'').replace(' tr.)','').replace('/','').replace('Xã, phường thuộc','').replace('Xã, thị trấn thuộc huyện','')
district = district.split('(')
districts = []
for x in district:
    if len(x) != 0:
        districts.append(x.strip())
# Out:
# ['thành phố Ninh Bình', 'Gia Viễn', 'Hoa Lư', 'Kim Sơn', 'Nho Quan', 'thành phố Tam Điệp', 'Yên Khánh', 'Yên Mô']

# %%
S = ''
for i in districts:
    S = S + "function(callback) {\n\tdistrictCreate('"+i+"', callback);\n},\n"
print (S)
# Out:
# function(callback) {
# 	districtCreate('thành phố Ninh Bình', callback);
# },
# function(callback) {
# 	districtCreate('Gia Viễn', callback);
# },
# function(callback) {
# 	districtCreate('Hoa Lư', callback);
# },
# function(callback) {
# 	districtCreate('Kim Sơn', callback);
# },
# function(callback) {
# 	districtCreate('Nho Quan', callback);
# },
# function(callback) {
# 	districtCreate('thành phố Tam Điệp', callback);
# },
# function(callback) {
# 	districtCreate('Yên Khánh', callback);
# },
# function(callback) {
# 	districtCreate('Yên Mô', callback);
# },

# %%
province = "An Giang/Bà Rịa Vũng Tàu/Bắc Giang/Bắc Kạn/Bạc Liêu/Bắc Ninh/Bến Tre/Bình Định/Bình Dương/Bình Phước/Bình Thuận/Cà Mau/Cao Bằng/Đắk Lắk/Đắk Nông/Điện Biên/Đồng Nai/Đồng Tháp/Gia Lai/Hà Giang/Hà Nam/Hà Tĩnh/Hải Dương/Hậu Giang/Hòa Bình/Hưng Yên/Khánh Hòa/Kiên Giang/Kon Tum/Lai Châu/Lâm Đồng/Lạng Sơn/Lào Cai/Long An/Nam Định/Nghệ An/Ninh Bình/Ninh Thuận/Phú Thọ/Quảng Bình/Quảng Nam/Quảng Ngãi/Quảng Ninh/Quảng Trị/Sóc Trăng/Sơn La/Tây Ninh/Thái Bình/Thái Nguyên/Thanh Hóa/Thừa Thiên Huế/Tiền Giang/Trà Vinh/Tuyên Quang/Vĩnh Long/Vĩnh Phúc/Yên Bái/Phú Yên/Cần Thơ/Đà Nẵng/Hải Phòng/Hà Nội/TP HCM"
province = province.split('/')
print (province)
# Out:
# ['An Giang', 'Bà Rịa Vũng Tàu', 'Bắc Giang', 'Bắc Kạn', 'Bạc Liêu', 'Bắc Ninh', 'Bến Tre', 'Bình Định', 'Bình Dương', 'Bình Phước', 'Bình Thuận', 'Cà Mau', 'Cao Bằng', 'Đắk Lắk', 'Đắk Nông', 'Điện Biên', 'Đồng Nai', 'Đồng Tháp', 'Gia Lai', 'Hà Giang', 'Hà Nam', 'Hà Tĩnh', 'Hải Dương', 'Hậu Giang', 'Hòa Bình', 'Hưng Yên', 'Khánh Hòa', 'Kiên Giang', 'Kon Tum', 'Lai Châu', 'Lâm Đồng', 'Lạng Sơn', 'Lào Cai', 'Long An', 'Nam Định', 'Nghệ An', 'Ninh Bình', 'Ninh Thuận', 'Phú Thọ', 'Quảng Bình', 'Quảng Nam', 'Quảng Ngãi', 'Quảng Ninh', 'Quảng Trị', 'Sóc Trăng', 'Sơn La', 'Tây Ninh', 'Thái Bình', 'Thái Nguyên', 'Thanh Hóa', 'Thừa Thiên Huế', 'Tiền Giang', 'Trà Vinh', 'Tuyên Quang', 'Vĩnh Long', 'Vĩnh Phúc', 'Yên Bái', 'Phú Yên', 'Cần Thơ', 'Đà Nẵng', 'Hải Phòng', 'Hà Nội', 'TP HCM']

# %%
S = ''
for i in province:
    S = S + "function(callback) {\n\tprovinceCreate('"+i+"', callback);\n},\n"
print (S)
# Out:
# function(callback) {
# 	'An Giang', provinceCreate(callback);
# },
# function(callback) {
# 	'Bà Rịa Vũng Tàu', provinceCreate(callback);
# },
# function(callback) {
# 	'Bắc Giang', provinceCreate(callback);
# },
# function(callback) {
# 	'Bắc Kạn', provinceCreate(callback);
# },
# function(callback) {
# 	'Bạc Liêu', provinceCreate(callback);
# },
# function(callback) {
# 	'Bắc Ninh', provinceCreate(callback);
# },
# function(callback) {
# 	'Bến Tre', provinceCreate(callback);
# },
# function(callback) {
# 	'Bình Định', provinceCreate(callback);
# },
# function(callback) {
# 	'Bình Dương', provinceCreate(callback);
# },
# function(callback) {
# 	'Bình Phước', provinceCreate(callback);
# },
# function(callback) {
# 	'Bình Thuận', provinceCreate(callback);
# },
# function(callback) {
# 	'Cà Mau', provinceCreate(callback);
# },
# function(callback) {
# 	'Cao Bằng', provinceCreate(callback);
# },
# function(callback) {
# 	'Đắk Lắk', provinceCreate(callback);
# },
# function(callback) {
# ...
